# %%
# %pip install python-binance

import requests as req
from binance.client import Client
from binance.enums import *
import config
import time
import datetime
import numpy as np
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cliente = Client(config.API_KEY, config.API_SECRET)

# %%
info = cliente.get_symbol_info('BTCUSDT')

# %%
info
# Out:
# {'symbol': 'BTCUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'BTC',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'PERCENT_PRICE',
#    'multiplierUp': '5',
#    'multiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00001000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00001000'},
#   {'filterType': 'MIN_NOTIONAL',
# ...

# %%
wallet = cliente.get_account_snapshot(type='SPOT')

# %%
wallet
# Out:
# {'code': 200,
#  'msg': '',
#  'snapshotVos': [{'type': 'spot',
#    'updateTime': 1667606399000,
#    'data': {'totalAssetOfBtc': '0.37470689',
#     'balances': [{'asset': 'AR', 'free': '82.008', 'locked': '0'},
#      {'asset': 'ATA', 'free': '0.71934677', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0.26676462', 'locked': '0'},
#      {'asset': 'CAKE', 'free': '0', 'locked': '0'},
#      {'asset': 'DOT', 'free': '28.4235576', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'EUR', 'free': '0', 'locked': '0'},
#      {'asset': 'FTM', 'free': '0.5', 'locked': '0'},
#      {'asset': 'GTC', 'free': '199.8', 'locked': '0'},
#      {'asset': 'IDEX', 'free': '23330.3173', 'locked': '0'},
#      {'asset': 'IOTA', 'free': '2399.714', 'locked': '0'},
#      {'asset': 'KLAY', 'free': '0.01867481', 'locked': '0'},
#      {'asset': 'LUNA', 'free': '0.23614274', 'locked': '0'},
# ...

# %%
dt = datetime.datetime.fromtimestamp(16676063990)

# %%
dt
# Out:
# datetime.datetime(2019, 4, 13, 12, 31, 55)

# %%
price = cliente.get_all_tickers()
price
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.07357100'},
#  {'symbol': 'LTCBTC', 'price': '0.00359400'},
#  {'symbol': 'BNBBTC', 'price': '0.01711500'},
#  {'symbol': 'NEOBTC', 'price': '0.00040000'},
#  {'symbol': 'QTUMETH', 'price': '0.00175500'},
#  {'symbol': 'EOSETH', 'price': '0.00073700'},
#  {'symbol': 'SNTETH', 'price': '0.00001778'},
#  {'symbol': 'BNTETH', 'price': '0.00030500'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00011920'},
#  {'symbol': 'BNBETH', 'price': '0.23270000'},
#  {'symbol': 'BTCUSDT', 'price': '16545.95000000'},
#  {'symbol': 'ETHUSDT', 'price': '1217.39000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00001099'},
# ...

# %%
price[1]['symbol']
# Out:
# 'LTCBTC'

# %%
list_USDT = []

for i in price:
    
    if 'USDT' in i['symbol']:
        list_USDT.append(i)
        
        
list_USDT
# Out:
# [{'symbol': 'BTCUSDT', 'price': '16545.95000000'},
#  {'symbol': 'ETHUSDT', 'price': '1217.39000000'},
#  {'symbol': 'BNBUSDT', 'price': '283.20000000'},
#  {'symbol': 'BCCUSDT', 'price': '448.70000000'},
#  {'symbol': 'NEOUSDT', 'price': '6.61000000'},
#  {'symbol': 'LTCUSDT', 'price': '59.46000000'},
#  {'symbol': 'QTUMUSDT', 'price': '2.14500000'},
#  {'symbol': 'ADAUSDT', 'price': '0.34450000'},
#  {'symbol': 'XRPUSDT', 'price': '0.36890000'},
#  {'symbol': 'EOSUSDT', 'price': '0.89400000'},
#  {'symbol': 'TUSDUSDT', 'price': '0.99990000'},
#  {'symbol': 'IOTAUSDT', 'price': '0.21920000'},
#  {'symbol': 'XLMUSDT', 'price': '0.09300000'},
#  {'symbol': 'ONTUSDT', 'price': '0.17300000'},
#  {'symbol': 'TRXUSDT', 'price': '0.05532000'},
#  {'symbol': 'ETCUSDT', 'price': '20.63000000'},
#  {'symbol': 'ICXUSDT', 'price': '0.15680000'},
#  {'symbol': 'VENUSDT', 'price': '0.00010000'},
#  {'symbol': 'NULSUSDT', 'price': '0.16730000'},
#  {'symbol': 'VETUSDT', 'price': '0.02079000'},
# ...

# %%
tickers = cliente.get_ticker()

# %%
tickers
# Out:
# [{'symbol': 'ETHBTC',
#   'priceChange': '0.00098300',
#   'priceChangePercent': '1.327',
#   'weightedAvgPrice': '0.07376888',
#   'prevClosePrice': '0.07408200',
#   'lastPrice': '0.07506500',
#   'lastQty': '0.72000000',
#   'bidPrice': '0.07506400',
#   'bidQty': '1.05800000',
#   'askPrice': '0.07506500',
#   'askQty': '0.04410000',
#   'openPrice': '0.07408200',
#   'highPrice': '0.07563800',
#   'lowPrice': '0.07213300',
#   'volume': '211950.30570000',
#   'quoteVolume': '15635.33663678',
#   'openTime': 1668091966655,
#   'closeTime': 1668178366655,
#   'firstId': 388761945,
#   'lastId': 389293044,
#   'count': 531100},
#  {'symbol': 'LTCBTC',
#   'priceChange': '0.00019100',
#   'priceChangePercent': '5.646',
#   'weightedAvgPrice': '0.00353515',
#   'prevClosePrice': '0.00338300',
#   'lastPrice': '0.00357400',
#   'lastQty': '1.88000000',
#   'bidPrice': '0.00357500',
#   'bidQty': '1.42900000',
#   'askPrice': '0.00357600',
#   'askQty': '2.80000000',
# ...
